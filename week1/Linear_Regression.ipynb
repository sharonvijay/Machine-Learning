# %% [markdown]
# Linear Regression

# %%
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **1. Linear regression**
# **Prepare data**
# First we will prepare some data for demonstrating linear regression. To keep things simple we will assume we have a single input feature. Let us use the following function to generate our data:
# ![image.png](data:image/png;base64,...)
#
# Where ![image.png](data:image/png;base64,...) is Gaussian noise.

# %%
number_of_samples = 100
x = np.linspace(-np.pi,np.pi,number_of_samples)
y = 0.5*x + np.sin(x)+np.random.random(x.shape)
plt.scatter(x,y,color='black')
plt.xlabel('x-input features')
plt.ylabel('y-input features')
plt.title('Fig For Data of Linear Regression')
plt.show()

# %%
print(x.shape)
# Out:
# (100,)

# %%
random_indices = np.random.permutation(number_of_samples)
#Training set  --70%
x_train = x[random_indices[:70]]
y_train = y[random_indices[:70]]

#Evaluation set  -- 15%
x_eval = x[random_indices[70:85]]
y_eval = y[random_indices[70:85]]

#Testing set    -- 15%
x_test = x[random_indices[85:]]
y_test = y[random_indices[85:]]

# %%
plt.scatter(x_test,y_test)
plt.show()

# %%
plt.scatter(x_train,y_train)
plt.show()

# %%
plt.scatter(x_eval,y_eval)
plt.show()

# %%
random_indices
# Out:
# array([73,  4,  3, 98,  6, 13, 61, 50, 29, 85, 83, 94, 41, 47, 93, 23, 53,
#        82, 51,  1, 63, 57, 18, 17, 33, 16, 54,  7, 36, 11, 72, 64, 15, 34,
#        56, 49, 19, 37, 52, 45, 25, 78, 48, 39, 43, 58, 44, 88, 60, 66, 74,
#        97, 96, 68, 30, 38, 27, 40, 79,  2, 69, 31, 92, 32, 22,  5, 46, 76,
#        91, 95, 12, 70, 59, 67, 75,  0, 24, 77, 42, 35, 10, 65, 20, 21, 80,
#        71, 28, 14, 62, 55,  9, 86, 99, 81, 89, 87, 26, 90,  8, 84])

# %%
model = linear_model.LinearRegression()
x_train_for_fit = np.matrix(x_train.reshape(len(x_train),1))
y_train_for_fit = np.matrix(y_train.reshape(len(y_train),1))


model.fit(x_train_for_fit,y_train_for_fit)


plt.scatter(x_train,y_train,color="black")
plt.plot(x.reshape(len(x),1),model.predict(x.reshape(len(x),1)))
plt.xlabel('x-input feature')
plt.ylabel('y-target values')
plt.title('Fig 2: Line fit to training data')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,

# %%
mean_eval_error = np.mean((y_eval - model.predict(x_eval.reshape(len(x_eval),1)))**2)

# %%
mean_eval_error
# Out:
# 4.60644822435736

# %%
mean_test_error = np.mean((y_test - model.predict(x_test.reshape(len(x_test),1)))**2)

# %%
mean_test_error
# Out:
# 5.616205697083843

# %%
mean_eval_error = np.mean( (y_eval - model.predict(x_eval.reshape(len(x_eval),1)))**2 )
mean_test_error = np.mean( (y_test - model.predict(x_test.reshape(len(x_test),1)))**2 )

print ('Validation MSE:', mean_eval_error, '\nTest MSE: ', mean_test_error)
# Out:
# Validation MSE: 4.60644822435736
# Test MSE:  5.616205697083843
